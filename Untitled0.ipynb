# %% [markdown]
# <a href="https://colab.research.google.com/github/anaberereta-hue/Reto-2-Base-de-datos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estructura de un Nodo
class Nodo:
 def __init__(self, dato):
 self.dato = dato # Valor almacenado
 self.siguiente = None # Enlace al próximo nodo
# Representación visual de una lista enlazada:
#
# cabeza
# |
# v
# [A|•]──► [B|•]──► [C|•]──► [D|None]
